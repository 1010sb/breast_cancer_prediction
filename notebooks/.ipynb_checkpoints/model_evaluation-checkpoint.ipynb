# %% [markdown]
# # Model Evaluation
# In this notebook, i will evaluate the performance of models using three feature selection techniques:
#
# 1. All Features
# 2. SelectKBest Features
# 3. RFE (Recursive Feature Elimination) Features

# %% [markdown]
# ### 1. All Features Evaluation Metrics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Load all features metrics data
df_all_features = pd.read_csv('../data/metrics_features_all.csv')
df_all_features
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score  \
# 0  Logistic_Regression  0.982456   0.976744  0.976744  0.976744
# 1                  SVM  0.973684   0.976190  0.953488  0.964706
# 2        Decision_Tree  0.938596   0.909091  0.930233  0.919540
# 3        Random_Forest  0.956140   0.952381  0.930233  0.941176
#
#                                   Best Parameters
# 0       {'C': 4.281332398719396, 'penalty': 'l2'}
# 1  {'C': 0.23357214690901212, 'kernel': 'linear'}
# 2           {'criterion': 'gini', 'max_depth': 4}
# 3           {'max_depth': 8, 'n_estimators': 100}

# %% [markdown]
# ### 1.1 Bar-chart for All Features Evaluation Metrics

# %%
# Unpivot dataframe to group scores by model and score type
df_melt = pd.melt(df_all_features, id_vars=['Model'], value_vars=['Accuracy', 'Precision', 'Recall', 'F1 Score'],
                  var_name='Score Type', value_name='Score')

# Round scores to two decimal places
df_melt['Score'] = df_melt['Score'].apply(lambda x: round(x, 2))


# Plot scores using seaborn
sns.set(style="whitegrid")
g = sns.catplot(x='Model', y='Score', hue='Score Type', kind='bar', data=df_melt, height=6, aspect=2)

# Add values to each bar
ax = g.facet_axis(0, 0)
for p in ax.containers:
    ax.bar_label(p, label_type='edge', fontsize=12, padding=2)

# Set plot title and subtitle
plt.subplots_adjust(top=0.9)
g.fig.suptitle('All Features - Evaluation Metrics', fontsize=16, fontweight='bold')
g.fig.subplots_adjust(top=0.85)
g.fig.text(0.5, 0.9, 'Breast Cancer Prediction - Model Performance', ha='center', fontsize=14)

plt.show()

# Save the plot
g.savefig('../images/all_features_metrics.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### 2 SelectKBest Evaluation Metrics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df_selectkbest = pd.read_csv('../data/metrics_features_SelectKBest.csv')
df_selectkbest
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score  \
# 0  Logistic_Regression  0.982456   0.976744  0.976744  0.976744
# 1                  SVM  0.982456   0.976744  0.976744  0.976744
# 2        Decision_Tree  0.938596   0.950000  0.883721  0.915663
# 3        Random_Forest  0.947368   0.951220  0.906977  0.928571
#
#                                 Best Parameters
# 0    {'C': 11.288378916846883, 'penalty': 'l2'}
# 1  {'C': 1.623776739188721, 'kernel': 'linear'}
# 2         {'criterion': 'gini', 'max_depth': 4}
# 3         {'max_depth': 10, 'n_estimators': 10}

# %% [markdown]
# ### 2.1 Bar-chart for SelectKBest Evaluation Metrics

# %%
# Unpivot dataframe to group scores by model and score type
df_melt = pd.melt(df_selectkbest, id_vars=['Model'], value_vars=['Accuracy', 'Precision', 'Recall', 'F1 Score'],
                  var_name='Score Type', value_name='Score')

# Round scores to two decimal places
df_melt['Score'] = df_melt['Score'].apply(lambda x: round(x, 2))


# Plot scores using seaborn
sns.set(style="whitegrid")
g = sns.catplot(x='Model', y='Score', hue='Score Type', kind='bar', data=df_melt, height=6, aspect=2)

# Add values to each bar
ax = g.facet_axis(0, 0)
for p in ax.containers:
    ax.bar_label(p, label_type='edge', fontsize=12, padding=2)

# Set plot title and subtitle
plt.subplots_adjust(top=0.9)
g.fig.suptitle('SelectKBest Features - Evaluation Metrics', fontsize=16, fontweight='bold')
g.fig.subplots_adjust(top=0.85)
g.fig.text(0.5, 0.9, 'Breast Cancer Prediction - Model Performance', ha='center', fontsize=14)

plt.show()

# Save the plot
g.savefig('../images/selectkbest_features_metrics.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### 3. RFE (Recursive Feature Elimination) Evaluation Metrics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df_RFE = pd.read_csv('../data/metrics_features_RFE.csv')
df_RFE
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score  \
# 0  Logistic_Regression  0.973684   0.976190  0.953488  0.964706
# 1                  SVM  0.973684   0.976190  0.953488  0.964706
# 2        Decision_Tree  0.938596   0.973684  0.860465  0.913580
# 3        Random_Forest  0.956140   0.952381  0.930233  0.941176
#
#                                Best Parameters
# 0  {'C': 0.23357214690901212, 'penalty': 'l2'}
# 1    {'C': 0.615848211066026, 'kernel': 'rbf'}
# 2     {'criterion': 'entropy', 'max_depth': 4}
# 3         {'max_depth': 8, 'n_estimators': 10}

# %% [markdown]
# ### 3.1 Bar-chart for RFE Evaluation Metrics

# %%
# Unpivot dataframe to group scores by model and score type
df_melt = pd.melt(df_RFE, id_vars=['Model'], value_vars=['Accuracy', 'Precision', 'Recall', 'F1 Score'],
                  var_name='Score Type', value_name='Score')

# Round scores to two decimal places
df_melt['Score'] = df_melt['Score'].apply(lambda x: round(x, 2))


# Plot scores using seaborn
sns.set(style="whitegrid")
g = sns.catplot(x='Model', y='Score', hue='Score Type', kind='bar', data=df_melt, height=6, aspect=2)

# Add values to each bar
ax = g.facet_axis(0, 0)
for p in ax.containers:
    ax.bar_label(p, label_type='edge', fontsize=12, padding=2)

# Set plot title and subtitle
plt.subplots_adjust(top=0.9)
g.fig.suptitle('RFE Features - Evaluation Metrics', fontsize=16, fontweight='bold')
g.fig.subplots_adjust(top=0.85)
g.fig.text(0.5, 0.9, 'Breast Cancer Prediction - Model Performance', ha='center', fontsize=14)

plt.show()

# Save the plot
g.savefig('../images/RFE_features_metrics.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Merging all metcis file to one Excel file

# %%
import pandas as pd

# Read the CSV files
df_all = pd.read_csv('../data/metrics_features_all.csv')
df_selectkbest = pd.read_csv('../data/metrics_features_SelectKBest.csv')
df_rfe = pd.read_csv('../data/metrics_features_RFE.csv')

# Merge the dataframes
df_merge = pd.concat([df_all, df_selectkbest, df_rfe], axis=0)

# Save the merged dataframe as an Excel file
df_merge.to_excel('../data/metrics_merged.xlsx', index=False)
